# %% [markdown]
# * **value** - the result of an expression; it can be stored in a variable, and you can do
# * **Object** - a thing with a value
# * **Data Type** - a category a value can belong to; all object jabe a data type; data types determine to a large extent of bahavior an object can have
# * **Class** - a definition of a data type; template for objects
# * **Instance** - an object of a particular data type; instances are produced by classes
# * **Property** - an object that belongs to another object and that is accessed using dot notation
#     * **Method** - a calablke property that operates on the value of the object it belongs to
#     * **Attribute** - a data property; a variable that belongs to the object
# * **'self' parameter** -
# * **'_init_' method** -

# %%
class Dog:
    def __init__(self, name, age, breed, color):
        self.name = name
        self.age = age
        self.breed = breed
        self.color = color
        
    def bark(self):
        print(f"my name is {self.name}!")
mydog = Dog("Fido, 12, golden retreiver, golden")
mydog.bark()
print(mydog.name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8     def bark(self):
#       9         print(f"my name is {self.name}!")
# ---> 10 mydog = Dog("Fido, 12, golden retreiver, golden")
#      11 mydog.bark()
#      12 print(mydog.name)
#
# TypeError: Dog.__init__() missing 3 required positional arguments: 'age', 'breed', and 'color'
